# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import datetime
import seaborn as sb

# %%
a=pd.read_csv("C:\\Users\\Nancy\\OneDrive\\Documents\\sem2\\sc1003\\project2\\CAC40.csv");
b=pd.read_excel("C:\\Users\\Nancy\\OneDrive\\Documents\\sem2\\sc1003\\project2\\SPY_2016_2021.xlsx");
c=pd.read_csv("C:\\Users\\Nancy\\OneDrive\\Documents\\sem2\\sc1003\\project2\\FTSE100.csv");

# %%
a.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  1998-01-02  3012.000000  3048.000000  3005.800049  3038.699951
# 1  1998-01-05  3023.399902  3075.300049  3023.399902  3072.800049
# 2  1998-01-06  3055.100098  3055.100098  3025.199951  3037.699951
# 3  1998-01-07  3012.800049  3062.199951  3006.699951  3006.699951
# 4  1998-01-08  3035.000000  3036.000000  2949.699951  2954.899902
#
#      Adj Close  Volume
# 0  3038.699951     0.0
# 1  3072.800049     0.0
# 2  3037.699951     0.0
# 3  3006.699951     0.0
# 4  2954.899902     0.0

# %%
b.head()
# Out:
#         Date       Close
# 0 2016-01-04  201.020004
# 1 2016-01-05  201.360001
# 2 2016-01-06  198.820007
# 3 2016-01-07  194.050003
# 4 2016-01-08  191.919998

# %%
c.head()
# Out:
#        Date     Open     High      Low    Close
# 0  12/31/21  7403.01  7403.01  7357.10  7384.54
# 1  12/30/21  7420.69  7433.39  7403.01  7403.01
# 2  12/29/21  7372.10  7457.14  7372.10  7420.69
# 3  12/28/21  7372.10  7372.10  7372.10  7372.10
# 4  12/27/21  7372.10  7372.10  7372.10  7372.10

# %%
#removing columns from CAC40
a=a.drop(labels=['Open', 'High', 'Low', 'Volume', 'Adj Close'], axis=1)
a.head()
# Out:
#          Date        Close
# 0  1998-01-02  3038.699951
# 1  1998-01-05  3072.800049
# 2  1998-01-06  3037.699951
# 3  1998-01-07  3006.699951
# 4  1998-01-08  2954.899902

# %%
b.head()
# Out:
#         Date       Close
# 0 2016-01-04  201.020004
# 1 2016-01-05  201.360001
# 2 2016-01-06  198.820007
# 3 2016-01-07  194.050003
# 4 2016-01-08  191.919998

# %%
#removing columns from FTSE100

c=c.drop(labels=[' Open', ' High', ' Low'],axis=1)
c.head()
# Out:
#        Date    Close
# 0  12/31/21  7384.54
# 1  12/30/21  7403.01
# 2  12/29/21  7420.69
# 3  12/28/21  7372.10
# 4  12/27/21  7372.10

# %%
c.columns #to check columns
# Out:
# Index(['Date', ' Close'], dtype='object')

# %%
#plot chart
plt.style.use('seaborn-muted')
plt.plot(a.Close)
plt.show()
#plot chart
plt.style.use('seaborn-muted')
plt.plot(b.Close)
plt.show()
#plot chart
c[" Close"].plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Generality of code
# It allows user to select which financial excel data file to be used

# %%
excel_file=input()
# Out:
# 1

# %%
if excel_file=='1':
    print("CAC40")
    print(a)
    df=a
elif excel_file=='2':
    print("SPY_2016_2021")
    print(b)
    df=b
elif excel_file=='3':
    print("FTSE 100")
    print(c)
    df=c
else:
    print("choose correct file")
# Out:
# CAC40
#             Date         Open         High          Low        Close  \
# 0     1998-01-02  3012.000000  3048.000000  3005.800049  3038.699951
# 1     1998-01-05  3023.399902  3075.300049  3023.399902  3072.800049
# 2     1998-01-06  3055.100098  3055.100098  3025.199951  3037.699951
# 3     1998-01-07  3012.800049  3062.199951  3006.699951  3006.699951
# 4     1998-01-08  3035.000000  3036.000000  2949.699951  2954.899902
# ...          ...          ...          ...          ...          ...
# 6173  2021-12-24  7091.600098  7116.879883  7086.580078  7086.580078
# 6174  2021-12-27  7070.140137  7149.140137  7062.399902  7140.390137
# 6175  2021-12-28  7141.850098  7187.759766  7141.669922  7181.109863
# 6176  2021-12-29  7179.109863  7201.649902  7137.350098  7161.520020
# 6177  2021-12-30  7167.529785  7189.839844  7156.790039  7173.229980
#
#         Adj Close      Volume
# 0     3038.699951         0.0
# 1     3072.800049         0.0
# 2     3037.699951         0.0
# 3     3006.699951         0.0
# 4     2954.899902         0.0
# ...           ...         ...
# 6173  7086.580078  11954300.0
# 6174  7140.390137  34917800.0
# 6175  7181.109863  36149600.0
# 6176  7161.520020  37481200.0
# 6177  7173.229980  35427000.0
#
# [6178 rows x 7 columns]

# %%
df.info()
df.head()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6178 entries, 0 to 6177
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6178 non-null   object
#  1   Open       6123 non-null   float64
#  2   High       6123 non-null   float64
#  3   Low        6123 non-null   float64
#  4   Close      6123 non-null   float64
#  5   Adj Close  6123 non-null   float64
#  6   Volume     6123 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 338.0+ KB
#             Date         Open         High          Low        Close  \
# 0     1998-01-02  3012.000000  3048.000000  3005.800049  3038.699951
# 1     1998-01-05  3023.399902  3075.300049  3023.399902  3072.800049
# 2     1998-01-06  3055.100098  3055.100098  3025.199951  3037.699951
# 3     1998-01-07  3012.800049  3062.199951  3006.699951  3006.699951
# 4     1998-01-08  3035.000000  3036.000000  2949.699951  2954.899902
# ...          ...          ...          ...          ...          ...
# 6173  2021-12-24  7091.600098  7116.879883  7086.580078  7086.580078
# 6174  2021-12-27  7070.140137  7149.140137  7062.399902  7140.390137
# 6175  2021-12-28  7141.850098  7187.759766  7141.669922  7181.109863
# 6176  2021-12-29  7179.109863  7201.649902  7137.350098  7161.520020
# 6177  2021-12-30  7167.529785  7189.839844  7156.790039  7173.229980
#
#         Adj Close      Volume
# 0     3038.699951         0.0
# 1     3072.800049         0.0
# 2     3037.699951         0.0
# 3     3006.699951         0.0
# 4     2954.899902         0.0
# ...           ...         ...
# 6173  7086.580078  11954300.0
# 6174  7140.390137  34917800.0
# 6175  7181.109863  36149600.0
# 6176  7161.520020  37481200.0
# 6177  7173.229980  35427000.0
#
# [6178 rows x 7 columns]

# %%
#plot chart
plt.style.use('seaborn-muted')
plt.plot(a.Close)
plt.show()

# %%
#calculate daily return
STARTING_BALANCE=1000000 #initial capital
df['Return'] = df.Close / df.Close.shift(1)
df.Return.iat[0] = 1
df['Bench_Bal'] = STARTING_BALANCE * df.Return.cumprod()

df
# Out:
#             Date         Open         High          Low        Close  \
# 0     1998-01-02  3012.000000  3048.000000  3005.800049  3038.699951
# 1     1998-01-05  3023.399902  3075.300049  3023.399902  3072.800049
# 2     1998-01-06  3055.100098  3055.100098  3025.199951  3037.699951
# 3     1998-01-07  3012.800049  3062.199951  3006.699951  3006.699951
# 4     1998-01-08  3035.000000  3036.000000  2949.699951  2954.899902
# ...          ...          ...          ...          ...          ...
# 6173  2021-12-24  7091.600098  7116.879883  7086.580078  7086.580078
# 6174  2021-12-27  7070.140137  7149.140137  7062.399902  7140.390137
# 6175  2021-12-28  7141.850098  7187.759766  7141.669922  7181.109863
# 6176  2021-12-29  7179.109863  7201.649902  7137.350098  7161.520020
# 6177  2021-12-30  7167.529785  7189.839844  7156.790039  7173.229980
#
#         Adj Close      Volume    Return     Bench_Bal
# 0     3038.699951         0.0  1.000000  1.000000e+06
# 1     3072.800049         0.0  1.011222  1.011222e+06
# 2     3037.699951         0.0  0.988577  9.996709e+05
# 3     3006.699951         0.0  0.989795  9.894692e+05
# 4     2954.899902         0.0  0.982772  9.724224e+05
# ...           ...         ...       ...           ...
# 6173  7086.580078  11954300.0  0.997246  1.822157e+06
# 6174  7140.390137  34917800.0  1.007593  1.835993e+06
# 6175  7181.109863  36149600.0  1.005703  1.846463e+06
# 6176  7161.520020  37481200.0  0.997272  1.841426e+06
# 6177  7173.229980  35427000.0  1.001635  1.844437e+06
#
# [6178 rows x 9 columns]

# %%
#calculate drawdown(calculatoing how much is dropped)
df['Bench_Peak'] = df.Bench_Bal.cummax()
df['Bench_DD'] = df.Bench_Bal - df.Bench_Peak

bench_dd = round((df.Bench_DD / df.Bench_Peak).min() * 100, 2)

bench_dd #will print worst drop down
# Out:
# -65.11

# %%
#calculating MACD
SEMA = df.Close.ewm(span = 12, adjust=False).mean()
LEMA = df.Close.ewm(span = 26, adjust=False).mean()

macd = SEMA - LEMA
signal = macd.ewm(span = 9, adjust=False).mean()
histogram=macd-signal
print(macd)
print(signal)
print(histogram)
print("the shorter term  EMA is",SEMA)
print("the longer tern EMA is",LEMA)
# Out:
# 0        0.000000
# 1        2.720236
# 2        2.020467
# 3       -1.023745
# 4       -7.529342
#           ...
# 6173    30.646346
# 6174    39.948778
# 6175    50.030048
# 6176    55.795614
# 6177    60.611076
# Name: Close, Length: 6178, dtype: float64
# 0        0.000000
# 1        0.544047
# 2        0.839331
# 3        0.466716
# 4       -1.132496
#           ...
# 6173    15.256473
# 6174    20.194934
# 6175    26.161957
# 6176    32.088688
# 6177    37.793166
# Name: Close, Length: 6178, dtype: float64
# 0        0.000000
# 1        2.176189
# 2        1.181136
# 3       -1.490461
# 4       -6.396846
#           ...
# 6173    15.389873
# 6174    19.753844
# 6175    23.868091
# 6176    23.706926
# 6177    22.817910
# Name: Close, Length: 6178, dtype: float64
# the shorter term  EMA is 0       3038.699951
# 1       3043.946120
# 2       3042.985171
# 3       3037.402829
# 4       3024.710071
#            ...
# 6173    6995.320189
# 6174    7017.638642
# 6175    7042.788061
# 6176    7061.054516
# 6177    7078.312280
# Name: Close, Length: 6178, dtype: float64
# the longer tern EMA is 0       3038.699951
# 1       3041.225884
# 2       3040.964704
# 3       3038.426574
# 4       3032.239413
#            ...
# 6173    6964.673843
# 6174    6977.689865
# 6175    6992.758013
# 6176    7005.258902
# 6177    7017.701204
# Name: Close, Length: 6178, dtype: float64

# %%
plt.figure()

#create subplot for price data
plt.subplot(211)
plt.plot(df.Close)

#create subplot for MACD
plt.subplot(212)
plt.plot(macd, color = 'y')
plt.plot(signal, color = 'g')

#show plot
plt.show()

# %%
#add column for entries (long when macd line above signal line. buy situation) )
df["macd"]=macd
df["signal"]=signal
df['histogram']=macd-signal


df['Buy_the_stock'] = macd > signal
df["sell_the_stock"]=signal>macd

df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 6173  2021-12-24  7091.600098  7116.879883  7086.580078  7086.580078
# 6174  2021-12-27  7070.140137  7149.140137  7062.399902  7140.390137
# 6175  2021-12-28  7141.850098  7187.759766  7141.669922  7181.109863
# 6176  2021-12-29  7179.109863  7201.649902  7137.350098  7161.520020
# 6177  2021-12-30  7167.529785  7189.839844  7156.790039  7173.229980
#
#         Adj Close      Volume    Return     Bench_Bal    Bench_Peak  \
# 6173  7086.580078  11954300.0  0.997246  1.822157e+06  1.874075e+06
# 6174  7140.390137  34917800.0  1.007593  1.835993e+06  1.874075e+06
# 6175  7181.109863  36149600.0  1.005703  1.846463e+06  1.874075e+06
# 6176  7161.520020  37481200.0  0.997272  1.841426e+06  1.874075e+06
# 6177  7173.229980  35427000.0  1.001635  1.844437e+06  1.874075e+06
#
#           Bench_DD       macd     signal  histogram  Buy_the_stock  \
# 6173 -51918.291973  30.646346  15.256473  15.389873           True
# 6174 -38082.230571  39.948778  20.194934  19.753844           True
# 6175 -27612.057527  50.030048  26.161957  23.868091           True
# 6176 -32649.150510  55.795614  32.088688  23.706926           True
# 6177 -29638.194407  60.611076  37.793166  22.817910           True
#
#       sell_the_stock
# 6173           False
# 6174           False
# 6175           False
# 6176           False
# 6177           False

# %%
w=pd.DataFrame(df[["Close","macd","signal","histogram"]])
w.head()
# Out:
#          Close      macd    signal  histogram
# 0  3038.699951  0.000000  0.000000   0.000000
# 1  3072.800049  2.720236  0.544047   2.176189
# 2  3037.699951  2.020467  0.839331   1.181136
# 3  3006.699951 -1.023745  0.466716  -1.490461
# 4  2954.899902 -7.529342 -1.132496  -6.396846

# %%
plt.figure()

#create subplot for price data
plt.subplot(211)
plt.plot(df.Close)

#create subplot for MACD
plt.subplot(212)
plt.plot(macd, color = 'y')
plt.plot(signal, color = 'g')

#show plot
plt.show()

# %%
w.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Close'}>,
#         <AxesSubplot:title={'center':'macd'}>],
#        [<AxesSubplot:title={'center':'signal'}>,
#         <AxesSubplot:title={'center':'histogram'}>]], dtype=object)

# %%
#calculating system return and balance
df['Sys_Ret'] = np.where(df.Buy_the_stock.shift(1) == True, df.Return, 1)

df['Sys_Bal'] = STARTING_BALANCE * df.Sys_Ret.cumprod()
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     1998-01-02  3012.000000  3048.000000  3005.800049  3038.699951
# 1     1998-01-05  3023.399902  3075.300049  3023.399902  3072.800049
# 2     1998-01-06  3055.100098  3055.100098  3025.199951  3037.699951
# 3     1998-01-07  3012.800049  3062.199951  3006.699951  3006.699951
# 4     1998-01-08  3035.000000  3036.000000  2949.699951  2954.899902
# ...          ...          ...          ...          ...          ...
# 6173  2021-12-24  7091.600098  7116.879883  7086.580078  7086.580078
# 6174  2021-12-27  7070.140137  7149.140137  7062.399902  7140.390137
# 6175  2021-12-28  7141.850098  7187.759766  7141.669922  7181.109863
# 6176  2021-12-29  7179.109863  7201.649902  7137.350098  7161.520020
# 6177  2021-12-30  7167.529785  7189.839844  7156.790039  7173.229980
#
#         Adj Close      Volume    Return     Bench_Bal    Bench_Peak  \
# 0     3038.699951         0.0  1.000000  1.000000e+06  1.000000e+06
# 1     3072.800049         0.0  1.011222  1.011222e+06  1.011222e+06
# 2     3037.699951         0.0  0.988577  9.996709e+05  1.011222e+06
# 3     3006.699951         0.0  0.989795  9.894692e+05  1.011222e+06
# 4     2954.899902         0.0  0.982772  9.724224e+05  1.011222e+06
# ...           ...         ...       ...           ...           ...
# 6173  7086.580078  11954300.0  0.997246  1.822157e+06  1.874075e+06
# 6174  7140.390137  34917800.0  1.007593  1.835993e+06  1.874075e+06
# 6175  7181.109863  36149600.0  1.005703  1.846463e+06  1.874075e+06
# 6176  7161.520020  37481200.0  0.997272  1.841426e+06  1.874075e+06
# 6177  7173.229980  35427000.0  1.001635  1.844437e+06  1.874075e+06
#
#           Bench_DD       macd     signal  histogram  Buy_the_stock  \
# 0         0.000000   0.000000   0.000000   0.000000          False
# 1         0.000000   2.720236   0.544047   2.176189           True
# 2    -11551.024638   2.020467   0.839331   1.181136           True
# 3    -21752.755805  -1.023745   0.466716  -1.490461          False
# 4    -38799.535624  -7.529342  -1.132496  -6.396846          False
# ...            ...        ...        ...        ...            ...
# 6173 -51918.291973  30.646346  15.256473  15.389873           True
# 6174 -38082.230571  39.948778  20.194934  19.753844           True
# 6175 -27612.057527  50.030048  26.161957  23.868091           True
# 6176 -32649.150510  55.795614  32.088688  23.706926           True
# 6177 -29638.194407  60.611076  37.793166  22.817910           True
#
#       sell_the_stock   Sys_Ret         Sys_Bal
# 0              False  1.000000  1000000.000000
# 1              False  1.000000  1000000.000000
# 2              False  0.988577   988577.161729
# 3               True  0.989795   978488.643275
# 4               True  1.000000   978488.643275
# ...              ...       ...             ...
# 6173           False  0.997246   579902.263495
# 6174           False  1.007593   584305.596933
# 6175           False  1.005703   587637.734722
# 6176           False  0.997272   586034.677370
# 6177           False  1.001635   586992.915650
#
# [6178 rows x 18 columns]

# %%
#calculating system drawdown
df['Sys_Peak'] = df.Sys_Bal.cummax()
df['Sys_DD'] = df.Sys_Bal - df.Sys_Peak

sys_dd = round((df.Sys_DD / df.Sys_Peak).min() * 100, 2)

sys_dd
# Out:
# -67.65

# %%
#annual wise return and drawdowns
#calculate metrics
#define backtest range
START = datetime.datetime(2000, 1, 1)
END = datetime.datetime(2020, 1, 1)
Years = (END - START).days / 365.25
bench_return = round(((df.Bench_Bal[1]/df.Bench_Bal[0]) - 1) * 100, 2)
bench_cagr = round(((((df.Bench_Bal[1]/df.Bench_Bal[0])**(1/Years))-1)*100), 2)
sys_ret = round(((df.Sys_Bal[1]/df.Sys_Bal[0]) - 1) * 100, 2)
sys_cagr = round(((((df.Sys_Bal[1]/df.Sys_Bal[0])**(1/Years))-1)*100), 2)

print(f'Benchmark Total return: {bench_return}%')
print(f'Benchmark CAGR: {bench_cagr}%')
print(f'Benchmark DD: {bench_dd}%')
print('')
print(f'System Total return: {sys_ret}%')
print(f'System CAGR: {sys_cagr}%')
print(f'System DD: {sys_dd}%')
# Out:
# Benchmark Total return: 1.12%
# Benchmark CAGR: 0.06%
# Benchmark DD: -65.11%
#
# System Total return: 0.0%
# System CAGR: 0.0%
# System DD: -67.65%

# %%
plt.plot(df.Bench_Bal)
plt.plot(df.Sys_Bal)

plt.show()

# %%
ax1 = plt.subplot2grid((8,1), (0,0), rowspan = 5, colspan = 1)
ax2 = plt.subplot2grid((8,1), (5,0), rowspan = 3, colspan = 1)

ax1.plot(df['Close'], color = 'green', linewidth = 1.5, label = 'close')


ax1.legend()
ax1.set_title('DF MACD SIGNALS')
ax2.plot(df['macd'], color = 'red', linewidth = 1.5, label = 'MACD')
ax2.plot(df['signal'], color = 'skyblue', linewidth = 1.5, label = 'SIGNAL')

for i in range(len(df)):
    if str(df['histogram'][i])[0] == '-':
        ax2.bar(df.index[i],df['histogram'][i], color = '#ef5350')
    else:
        ax2.bar(df.index[i], df['histogram'][i], color = '#26a69a')
        
plt.legend(loc = 'lower right')
plt.show()

# %%
def plot_macd( macd, signal, hist):
    ax1 = plt.subplot2grid((9,1), (0,0), rowspan = 5, colspan = 1)
    ax2 = plt.subplot2grid((8,1), (5,0), rowspan = 3, colspan = 1)

    ax1.plot('Close',color='red',linewidth=1.5,label='Close')
    ax2.plot(macd, color = 'grey', linewidth = 1.5, label = 'MACD')
    ax2.plot(signal, color = 'skyblue', linewidth = 1.5, label = 'SIGNAL')

    for i in range(len('Close')):
        if str(hist[i])[0] == '-':
            ax2.bar(df.index[i], hist[i], color = '#ef5350')
        else:
            ax2.bar(df.index[i], hist[i], color = '#26a69a')

    plt.legend(loc = 'lower right')

plot_macd( df['macd'], df['signal'], df['histogram'])

# %%
#total number of trades made using MACD

total=len("Close")
print(total)
buy=len("Buy_the_stock")
print(buy)
# Out:
# 5
# 13

# %%
df["Sys_Ret"]
# Out:
# 0       1.000000
# 1       1.000000
# 2       0.988577
# 3       0.989795
# 4       1.000000
#           ...
# 6173    0.997246
# 6174    1.007593
# 6175    1.005703
# 6176    0.997272
# 6177    1.001635
# Name: Sys_Ret, Length: 6178, dtype: float64

# %%
#average return per trade
#total sum
sumtotal=df["Sys_Ret"].sum()
print (sumtotal)

#total length
length=len(df["Sys_Ret"])
print(length)
#average
avg=sumtotal/length
print(avg)
# Out:
# 6115.711000430681
# 6178
# 0.9899176109470187

# %%
df.sum(axis=1,skipna=True)
# Out:
# C:\Users\Nancy\AppData\Local\Temp\ipykernel_11320\791661922.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum(axis=1,skipna=True)
# 0       4.003041e+06
# 1       4.025525e+06
# 2       3.979541e+06
# 3       3.938923e+06
# 4       3.904765e+06
#             ...
# 6173    4.811269e+06
# 6174    4.847820e+06
# 6175    4.875485e+06
# 6176    4.862197e+06
# 6177    4.870157e+06
# Length: 6178, dtype: float64

# %%
#relative gain
df["Sys_Ret"]
# Out:
# 0       1.000000
# 1       1.000000
# 2       0.988577
# 3       0.989795
# 4       1.000000
#           ...
# 6173    0.997246
# 6174    1.007593
# 6175    1.005703
# 6176    0.997272
# 6177    1.001635
# Name: Sys_Ret, Length: 6178, dtype: float64

# %%
#realtive loss
df["Sys_DD"]
# Out:
# 0            0.000000
# 1            0.000000
# 2       -11422.838271
# 3       -21511.356725
# 4       -21511.356725
#             ...
# 6173   -730986.940512
# 6174   -726583.607075
# 6175   -723251.469285
# 6176   -724854.526637
# 6177   -723896.288357
# Name: Sys_DD, Length: 6178, dtype: float64
